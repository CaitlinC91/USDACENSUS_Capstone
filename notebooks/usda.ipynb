# %%
import json
import requests
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
import re

# %%
with open('key.json') as fi:
    credentials = json.load(fi)

api_key = credentials['api_key']

# %%
call = "https://quickstats.nass.usda.gov/api/api_GET/?key=" + api_key + "&source_desc=CENSUS&sector_desc=CROPS&agg_level_desc=STATE&year__GE=2017&state_alpha="

res_2017 = []
states = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'IA','ME', 'MD','MA', 'MI','MN', 'MS','MO', 'MT','NE','NV','NH', 'NJ','NM', 'NY','NC', 'ND','OH', 'OK','OR', 'PA','RI','SC','SD', 'TN','TX','UT','VT','VA','WA','WV','WI','WY']  # List of states to iterate over

for state in states:
    endpoint = call + state  
    result = requests.get(endpoint)  
    res_2017.append(result.json()) 
    print(result)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
res_2017[0]['data']
# Out:
# [{'class_desc': 'ALL CLASSES',
#   'watershed_desc': '',
#   'begin_code': '00',
#   'group_desc': 'CROP TOTALS',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01',
#   'county_ansi': '',
#   'county_name': '',
#   'county_code': '',
#   'watershed_code': '00000000',
#   'state_name': 'ALABAMA',
#   'year': 2017,
#   'end_code': '00',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'sector_desc': 'CROPS',
#   'domaincat_desc': 'IRRIGATION STATUS: (ANY ON OPERATION)',
#   'load_time': '2018-02-01 00:00:00.000',
#   'CV (%)': '5.2',
#   'state_fips_code': '01',
#   'location_desc': 'ALABAMA',
#   'source_desc': 'CENSUS',
#   'asd_code': '',
#   'country_name': 'UNITED STATES',
#   'asd_desc': '',
#   'commodity_desc': 'CROP TOTALS',
#   'state_alpha': 'AL',
#   'freq_desc': 'ANNUAL',
#   'zip_5': '',
#   'country_code': '9000',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'statisticcat_desc': 'SALES',
#   'unit_desc': '$',
# ...

# %%
#This makes a usable DF. Need to create loop to run all 50 indexes
useable = pd.json_normalize(res_2017[0]['data'])

# %%
total_2017df = pd.DataFrame()  # Initialize an empty DataFrame to store the merged results

for x in range(50):
    df = pd.json_normalize(res_2017[x]['data'])
    total_2017df = pd.concat([total_2017df, df], ignore_index=True)

# %%
call2 = "https://quickstats.nass.usda.gov/api/api_GET/?key=" + api_key +"&source_desc=CENSUS&sector_desc=CROPS&agg_level_desc=STATE&year=2012&state_alpha="

res_2012 = []
states = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'IA','ME', 'MD','MA', 'MI','MN', 'MS','MO', 'MT','NE','NV','NH', 'NJ','NM', 'NY','NC', 'ND','OH', 'OK','OR', 'PA','RI','SC','SD', 'TN','TX','UT','VT','VA','WA','WV','WI','WY']  # List of states to iterate over

for state in states:
    endpoint2 = call2 + state  
    result = requests.get(endpoint2)  
    res_2012.append(result.json())  
    print(result)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
pd.json_normalize(res_2012[0]['data'])
# Out:
#       year county_code county_name watershed_code state_name  \
# 0     2012                               00000000    ALABAMA
# 1     2012                               00000000    ALABAMA
# 2     2012                               00000000    ALABAMA
# 3     2012                               00000000    ALABAMA
# 4     2012                               00000000    ALABAMA
# ...    ...         ...         ...            ...        ...
# 9870  2012                               00000000    ALABAMA
# 9871  2012                               00000000    ALABAMA
# 9872  2012                               00000000    ALABAMA
# 9873  2012                               00000000    ALABAMA
# 9874  2012                               00000000    ALABAMA
#
#                                          domaincat_desc  \
# 0                 IRRIGATION STATUS: (ANY ON OPERATION)
# 1     IRRIGATION STATUS: (HARVESTED CROPLAND IS ENTI...
# 2                IRRIGATION STATUS: (NONE ON OPERATION)
# ...

# %%
total_2012df = pd.DataFrame()  # Initialize an empty DataFrame to store the merged results

for x in range(50):
    df = pd.json_normalize(res_2012[x]['data'])
    total_2012df = pd.concat([total_2012df, df], ignore_index=True)

# %%
total_2012df
# Out:
#         year county_code county_name watershed_code state_name  \
# 0       2012                               00000000    ALABAMA
# 1       2012                               00000000    ALABAMA
# 2       2012                               00000000    ALABAMA
# 3       2012                               00000000    ALABAMA
# 4       2012                               00000000    ALABAMA
# ...      ...         ...         ...            ...        ...
# 462462  2012                               00000000    WYOMING
# 462463  2012                               00000000    WYOMING
# 462464  2012                               00000000    WYOMING
# 462465  2012                               00000000    WYOMING
# 462466  2012                               00000000    WYOMING
#
#                                            domaincat_desc  \
# 0                   IRRIGATION STATUS: (ANY ON OPERATION)
# 1       IRRIGATION STATUS: (HARVESTED CROPLAND IS ENTI...
# ...

# %%
call3 = "https://quickstats.nass.usda.gov/api/api_GET/?key=" + api_key + "&source_desc=CENSUS&sector_desc=CROPS&agg_level_desc=STATE&year=2007&state_alpha="

res_2007 = []
states = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'IA','ME', 'MD','MA', 'MI','MN', 'MS','MO', 'MT','NE','NV','NH', 'NJ','NM', 'NY','NC', 'ND','OH', 'OK','OR', 'PA','RI','SC','SD', 'TN','TX','UT','VT','VA','WA','WV','WI','WY']  # List of states to iterate over

for state in states:
    endpoint3 = call3 + state  
    result = requests.get(endpoint3)  
    res_2007.append(result.json())  
    print(result)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
total_2007df = pd.DataFrame()  # Initialize an empty DataFrame to store the merged results

for x in range(50):
    df = pd.json_normalize(res_2007[x]['data'])
    total_2007df = pd.concat([total_2007df, df], ignore_index=True)

# %%
total_2007df
# Out:
#        freq_desc       prodn_practice_desc watershed_desc statisticcat_desc  \
# 0         ANNUAL  ALL PRODUCTION PRACTICES                            SALES
# 1         ANNUAL  ALL PRODUCTION PRACTICES                            SALES
# 2         ANNUAL  ALL PRODUCTION PRACTICES                            SALES
# 3         ANNUAL  ALL PRODUCTION PRACTICES                            SALES
# 4         ANNUAL  ALL PRODUCTION PRACTICES                            SALES
# ...          ...                       ...            ...               ...
# 110725    ANNUAL               IN THE OPEN                            SALES
# 110726    ANNUAL  ALL PRODUCTION PRACTICES                   AREA HARVESTED
# 110727    ANNUAL  ALL PRODUCTION PRACTICES                   AREA HARVESTED
# 110728    ANNUAL  ALL PRODUCTION PRACTICES                   AREA HARVESTED
# 110729    ANNUAL  ALL PRODUCTION PRACTICES                   AREA HARVESTED
#
# ...

# %%
call4 = "https://quickstats.nass.usda.gov/api/api_GET/?key=" + api_key + "&source_desc=CENSUS&sector_desc=CROPS&agg_level_desc=STATE&year=2002&state_alpha="

res_2002 = []
states = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'IA','ME', 'MD','MA', 'MI','MN', 'MS','MO', 'MT','NE','NV','NH', 'NJ','NM', 'NY','NC', 'ND','OH', 'OK','OR', 'PA','RI','SC','SD', 'TN','TX','UT','VT','VA','WA','WV','WI','WY']  # List of states to iterate over

for state in states:
    endpoint4 = call4 + state  
    result = requests.get(endpoint4)  
    res_2002.append(result.json())  
    print(result)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
total_2002df = pd.DataFrame()  # Initialize an empty DataFrame to store the merged results

for x in range(50):
    df = pd.json_normalize(res_2002[x]['data'])
    total_2002df = pd.concat([total_2002df, df], ignore_index=True)

# %%
call5 = "https://quickstats.nass.usda.gov/api/api_GET/?key=" + api_key + "&source_desc=CENSUS&sector_desc=CROPS&agg_level_desc=STATE&year=1997&state_alpha="

res_1997 = []
states = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'IA','ME', 'MD','MA', 'MI','MN', 'MS','MO', 'MT','NE','NV','NH', 'NJ','NM', 'NY','NC', 'ND','OH', 'OK','OR', 'PA','RI','SC','SD', 'TN','TX','UT','VT','VA','WA','WV','WI','WY']  # List of states to iterate over

for state in states:
    endpoint5 = call5 + state  
    result = requests.get(endpoint5)  
    res_1997.append(result.json())  
    print(result)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
total_1997df = pd.DataFrame()  # Initialize an empty DataFrame to store the merged results

for x in range(50):
    df = pd.json_normalize(res_1997[x]['data'])
    total_1997df = pd.concat([total_1997df, df], ignore_index=True)

# %%
#merga dfs together into one big lovely df
frames = [total_2017df, total_2012df, total_2007df, total_2002df, total_1997df]
 
usda_census = pd.concat(frames)
usda_census
# Out:
#         class_desc watershed_desc begin_code   group_desc  \
# 0      ALL CLASSES                        00  CROP TOTALS
# 1      ALL CLASSES                        00  CROP TOTALS
# 2      ALL CLASSES                        00  CROP TOTALS
# 3      ALL CLASSES                        00  CROP TOTALS
# 4      ALL CLASSES                        00  CROP TOTALS
# ...            ...            ...        ...          ...
# 31631  ALL CLASSES                        00   VEGETABLES
# 31632  ALL CLASSES                        00   VEGETABLES
# 31633  ALL CLASSES                        00   VEGETABLES
# 31634  ALL CLASSES                        00   VEGETABLES
# 31635  ALL CLASSES                        00   VEGETABLES
#
#             prodn_practice_desc state_ansi county_ansi county_name  \
# 0      ALL PRODUCTION PRACTICES         01
# 1      ALL PRODUCTION PRACTICES         01
# 2      ALL PRODUCTION PRACTICES         01
# 3      ALL PRODUCTION PRACTICES         01
# ...

# %%
#Need to change some datatypes and drop some uneeded columns
usda_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1508855 entries, 0 to 31635
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   class_desc             1508855 non-null  object
#  1   watershed_desc         1508855 non-null  object
#  2   begin_code             1508855 non-null  object
#  3   group_desc             1508855 non-null  object
#  4   prodn_practice_desc    1508855 non-null  object
#  5   state_ansi             1508855 non-null  object
#  6   county_ansi            1508855 non-null  object
#  7   county_name            1508855 non-null  object
#  8   county_code            1508855 non-null  object
#  9   watershed_code         1508855 non-null  object
#  10  state_name             1508855 non-null  object
#  11  year                   1508855 non-null  int64
#  12  end_code               1508855 non-null  object
#  13  short_desc             1508855 non-null  object
# ...

# %%
#Cleaning dataframe
usda_census.columns = map(str.lower, usda_census.columns)
usda_census['value'] = pd.to_numeric(usda_census['value'],errors='coerce')

# %%
# saving the DataFrame as a CSV file
usda_census_csv = usda_census.to_csv('usda_census.csv', index = True)
print('\nCSV String:\n', usda_census_csv)
# Out:
# CSV String:
#  None

# %%
usda_census = pd.read_csv('../data/usda_census.csv')
usda_census.info()
# Out:
# C:\Users\Aaron\AppData\Local\Temp\ipykernel_39824\3343532230.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   usda_census = pd.read_csv('../data/usda_census.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1508855 entries, 0 to 1508854
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Unnamed: 0             1508855 non-null  int64
#  1   class_desc             1508855 non-null  object
#  2   watershed_desc         0 non-null        float64
#  3   begin_code             1508855 non-null  int64
#  4   group_desc             1508855 non-null  object
#  5   prodn_practice_desc    1508855 non-null  object
#  6   state_ansi             1508855 non-null  int64
#  7   county_ansi            0 non-null        float64
#  8   county_name            0 non-null        float64
# ...

# %%
#Trying to understnad value
usda_census[usda_census['unit_desc'] != 'OPERATIONS']
# Out:
#          Unnamed: 0   class_desc  watershed_desc  begin_code   group_desc  \
# 0                 0  ALL CLASSES             NaN           0  CROP TOTALS
# 1                 1  ALL CLASSES             NaN           0  CROP TOTALS
# 2                 2  ALL CLASSES             NaN           0  CROP TOTALS
# 3                 3  ALL CLASSES             NaN           0  CROP TOTALS
# 4                 4  ALL CLASSES             NaN           0  CROP TOTALS
# ...             ...          ...             ...         ...          ...
# 1508845       31626  ALL CLASSES             NaN           0   VEGETABLES
# 1508847       31628  ALL CLASSES             NaN           0   VEGETABLES
# 1508849       31630  ALL CLASSES             NaN           0   VEGETABLES
# 1508851       31632  ALL CLASSES             NaN           0   VEGETABLES
# 1508853       31634  ALL CLASSES             NaN           0   VEGETABLES
#
#               prodn_practice_desc  state_ansi  county_ansi  county_name  \
# ...

# %%
#Created a State df to analyze
#cabbage = usda_census[usda_census['short_desc'].str.startswith("cabbage")]
AL = usda_census[usda_census['state_alpha'] == 'AL']

# %%
#cabbage = AL[AL['short_desc'].str.startswith('cabbage')]
cabbage = AL[AL['commodity_desc'] == 'CABBAGE']
cabbage['value'].median()
# Out:
# 4.5

# %%
#top value items in AL
al_eda = AL.groupby(['commodity_desc','unit_desc'])['value'].sum().sort_values(ascending=False)

# %%
al_eda.head(30)
# Out:
# commodity_desc           unit_desc
# HAY & HAYLAGE            OPERATIONS    84444.0
# CORN                     OPERATIONS    72938.0
# COTTON                   OPERATIONS    67360.0
# VEGETABLE TOTALS         OPERATIONS    65567.0
# SOYBEANS                 OPERATIONS    56025.0
# HAY                      ACRES         55350.0
# VEGETABLE TOTALS         ACRES         49354.0
# ORCHARDS                 ACRES         49223.0
# HAY                      OPERATIONS    48360.0
# ORCHARDS                 OPERATIONS    45401.0
# CORN                     ACRES         44562.0
# FIELD CROPS, OTHER       OPERATIONS    41971.0
# PECANS                   ACRES         41903.0
# WHEAT                    OPERATIONS    37727.0
# GRAIN                    OPERATIONS    34448.0
# PECANS                   OPERATIONS    33284.0
# WHEAT                    ACRES         32372.0
# PEANUTS                  OPERATIONS    28021.0
# PEACHES                  ACRES         26219.0
# ...

# %%
al_soybeans = AL[(AL['commodity_desc'] == 'SOYBEANS')& (AL['year'] == 2017)]
al_soybeans
# Out:
#       Unnamed: 0   class_desc  watershed_desc  begin_code   group_desc  \
# 4252        4252  ALL CLASSES             NaN           0  FIELD CROPS
# 4253        4253  ALL CLASSES             NaN           0  FIELD CROPS
# 4254        4254  ALL CLASSES             NaN           0  FIELD CROPS
# 4255        4255  ALL CLASSES             NaN           0  FIELD CROPS
# 4256        4256  ALL CLASSES             NaN           0  FIELD CROPS
# ...          ...          ...             ...         ...          ...
# 4859        4859  ALL CLASSES             NaN           0  FIELD CROPS
# 4860        4860  ALL CLASSES             NaN           0  FIELD CROPS
# 4861        4861  ALL CLASSES             NaN           0  FIELD CROPS
# 4862        4862  ALL CLASSES             NaN           0  FIELD CROPS
# 4863        4863  ALL CLASSES             NaN           0  FIELD CROPS
#
#                                  prodn_practice_desc  state_ansi  county_ansi  \
# ...

# %%
#Finding highest yield crops by year for AL
yield_AL = AL[(AL['domain_desc']=='TOTAL') & (AL['statisticcat_desc'] == 'YIELD')].groupby(['commodity_desc', 'year']).median('value')

# %%
AL.year.unique()
# Out:
# array([2017, 2021, 2019, 2018, 2012, 2007, 2002, 1997], dtype=int64)

# %%
AL_1997 = AL[AL['year']== 1997]

# %%
yield_usda_census = usda_census[(usda_census['domain_desc']=='TOTAL') & (usda_census['statisticcat_desc'] == 'YIELD')].groupby(['location_desc','commodity_desc', 'year']).median('value')

# %%
yield_usda_census.to_csv('yield_usda_census.csv', index = True)
print('\nCSV String:\n', 'yield_usda_census_csv')
# Out:
# CSV String:
#  yield_usda_census_csv

# %%
# Create a dictionary mapping states to regions
region_mapping = {
    'TN': 'SOUTH EASTERN',
    'NC': 'SOUTH EASTERN',
    'SC': 'SOUTH EASTERN',
    'GA': 'SOUTH EASTERN',
    'AL': 'SOUTH EASTERN',
    'MS': 'SOUTH EASTERN',
    'FL': 'SOUTH EASTERN',
    'KY': 'NORTH EASTERN',
    'VA': 'NORTH EASTERN',
    'WV': 'NORTH EASTERN',
    'IN': 'NORTH EASTERN',
    'OH': 'NORTH EASTERN',
    'MI': 'NORTH EASTERN',
    'PA': 'NORTH EASTERN',
    'DC': 'NORTH EASTERN',
    'DE': 'NORTH EASTERN',
    'NJ': 'NORTH EASTERN',
    'NY': 'NORTH EASTERN',
    'CT': 'NORTH EASTERN',
    'MA': 'NORTH EASTERN',
    'VT': 'NORTH EASTERN',
    'NH': 'NORTH EASTERN',
    'ME': 'NORTH EASTERN',
    'RI': 'NORTH EASTERN',
    'ND': 'NORTH CENTRAL',
    'MN': 'NORTH CENTRAL',
    'WI': 'NORTH CENTRAL',
    'SD': 'NORTH CENTRAL',
    'NE': 'NORTH CENTRAL',
    'KS': 'NORTH CENTRAL',
    'MO': 'NORTH CENTRAL',
    'IL': 'NORTH CENTRAL',
    'IA': 'NORTH CENTRAL',
    'OK': 'SOUTH CENTRAL',
    'AR': 'SOUTH CENTRAL',
    'LA': 'SOUTH CENTRAL',
    'TX': 'SOUTH CENTRAL',
    'CA': 'SOUTH WEST',
    'NV': 'SOUTH WEST',
    'UT': 'SOUTH WEST',
    'AZ': 'SOUTH WEST',
    'CO': 'SOUTH WEST',
    'NM': 'SOUTH WEST',
    'WA': 'NORTH WEST',
    'OR': 'NORTH WEST',
    'ID': 'NORTH WEST',
    'MT': 'NORTH WEST',
    'WY': 'NORTH WEST',


}

# Create a 'region' column based on the 'states' column
usda_census['region'] = usda_census['state_alpha'].map(region_mapping)

usda_census.head()
# Out:
#    Unnamed: 0   class_desc  watershed_desc  begin_code   group_desc  \
# 0           0  ALL CLASSES             NaN           0  CROP TOTALS
# 1           1  ALL CLASSES             NaN           0  CROP TOTALS
# 2           2  ALL CLASSES             NaN           0  CROP TOTALS
# 3           3  ALL CLASSES             NaN           0  CROP TOTALS
# 4           4  ALL CLASSES             NaN           0  CROP TOTALS
#
#         prodn_practice_desc  state_ansi  county_ansi  county_name  \
# 0  ALL PRODUCTION PRACTICES           1          NaN          NaN
# 1  ALL PRODUCTION PRACTICES           1          NaN          NaN
# 2  ALL PRODUCTION PRACTICES           1          NaN          NaN
# 3  ALL PRODUCTION PRACTICES           1          NaN          NaN
# 4  ALL PRODUCTION PRACTICES           1          NaN          NaN
#
#    county_code  ...  statisticcat_desc unit_desc  week_ending  agg_level_desc  \
# ...

# %%
# aggregating domain_desc Totals, by regions

region_totals = usda_census[usda_census['domain_desc']=='TOTAL'].groupby(['region', 'year'])['value'].median()
region_totals
# Out:
# region         year
# NORTH CENTRAL  1997    43.0
#                2002    27.0
#                2007    24.0
#                2012    26.0
#                2017    29.0
#                2018    35.0
#                2019     7.0
# NORTH EASTERN  1997    48.0
#                2002    34.0
#                2007    29.0
#                2012    30.0
#                2017    33.0
#                2018    46.5
#                2019     8.0
# NORTH WEST     1997    58.0
#                2002    38.0
#                2007    30.0
#                2012    27.0
#                2017    26.5
#                2018    35.0
#                2019     6.0
# SOUTH CENTRAL  1997    79.0
#                2002    40.2
#                2007    29.0
#                2012    27.0
#                2017    32.0
#                2018    32.0
#                2019     4.0
# SOUTH EASTERN  1997    81.5
#                2002    43.0
#                2007    31.0
#                2012    30.0
# ...

# %%
regions_eda = usda_census[usda_census['domain_desc']=='TOTAL']
regions_eda
# Out:
#          Unnamed: 0   class_desc  watershed_desc  begin_code   group_desc  \
# 54               54  ALL CLASSES             NaN           0  CROP TOTALS
# 58               58  ALL CLASSES             NaN           0  CROP TOTALS
# 59               59  ALL CLASSES             NaN           0  CROP TOTALS
# 60               60  ALL CLASSES             NaN           0  CROP TOTALS
# 72               72  ALL CLASSES             NaN           0  CROP TOTALS
# ...             ...          ...             ...         ...          ...
# 1508850       31631  ALL CLASSES             NaN           0   VEGETABLES
# 1508851       31632  ALL CLASSES             NaN           0   VEGETABLES
# 1508852       31633  ALL CLASSES             NaN           0   VEGETABLES
# 1508853       31634  ALL CLASSES             NaN           0   VEGETABLES
# 1508854       31635  ALL CLASSES             NaN           0   VEGETABLES
#
#               prodn_practice_desc  state_ansi  county_ansi  county_name  \
# ...

# %%
regions_eda.to_csv('regions_eda.csv', index = True)
print('\nCSV String:\n', 'regions_eda_csv')
# Out:
# CSV String:
#  regions_eda_csv
