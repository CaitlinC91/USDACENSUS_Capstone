# %%
import json
import requests
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.dates as mdates

# %%
call = "https://quickstats.nass.usda.gov/api/api_GET/?key=" + api_key + "&source_desc=CENSUS&sector_desc=CROPS&agg_level_desc=STATE&year__GE=2017&state_alpha="

res_2017 = []
states = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'IA','ME', 'MD','MA', 'MI','MN', 'MS','MO', 'MT','NE','NV','NH', 'NJ','NM', 'NY','NC', 'ND','OH', 'OK','OR', 'PA','RI','SC','SD', 'TN','TX','UT','VT','VA','WA','WV','WI','WY']  # List of states to iterate over

for state in states:
    endpoint = call + state  
    result = requests.get(endpoint)  
    res_2017.append(result.json()) 
    print(result)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
res_2017[0]['data']
# Out:
# [{'end_code': '00',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'IRRIGATION STATUS',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'week_ending': '',
#   'reference_period_desc': 'YEAR',
#   'Value': '593,448,000',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'year': 2017,
#   'load_time': '2018-02-01 00:00:00.000',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'domaincat_desc': 'IRRIGATION STATUS: (ANY ON OPERATION)',
#   'region_desc': '',
#   'county_name': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'county_code': '',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'group_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'CV (%)': '5.2',
#   'state_fips_code': '01'},
#  {'unit_desc': '$',
#   'watershed_desc': '',
#   'year': 2017,
#   'load_time': '2018-02-01 00:00:00.000',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'domaincat_desc': 'IRRIGATION STATUS: (HARVESTED CROPLAND IS ENTIRELY IRRIGATED)',
#   'region_desc': '',
#   'county_name': '',
#   'state_alpha': 'AL',
#   'county_code': '',
#   'asd_code': '',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00',
#   'CV (%)': '7.1',
#   'group_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'state_fips_code': '01',
#   'end_code': '00',
#   'domain_desc': 'IRRIGATION STATUS',
#   'freq_desc': 'ANNUAL',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01',
#   'week_ending': '',
#   'Value': '205,941,000',
#   'reference_period_desc': 'YEAR',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'zip_5': '',
#   'country_name': 'UNITED STATES'},
#  {'load_time': '2018-02-01 00:00:00.000',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'domaincat_desc': 'IRRIGATION STATUS: (NONE ON OPERATION)',
#   'region_desc': '',
#   'county_name': '',
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'year': 2017,
#   'state_fips_code': '01',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'group_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'CV (%)': '5.1',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'end_code': '00',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'IRRIGATION STATUS',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'reference_period_desc': 'YEAR',
#   'Value': '618,882,000',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'week_ending': ''},
#  {'load_time': '2018-02-01 00:00:00.000',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (111)',
#   'county_name': '',
#   'region_desc': '',
#   'unit_desc': '$',
#   'watershed_desc': '',
#   'year': 2017,
#   'state_fips_code': '01',
#   'county_code': '',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00',
#   'CV (%)': '2.8',
#   'state_name': 'ALABAMA',
#   'group_desc': 'CROP TOTALS',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'end_code': '00',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'freq_desc': 'ANNUAL',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'reference_period_desc': 'YEAR',
#   'Value': '1,131,395,000',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01',
#   'week_ending': ''},
#  {'state_fips_code': '01',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'group_desc': 'CROP TOTALS',
#   'CV (%)': '5.6',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (1111)',
#   'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'Value': '303,284,000',
#   'reference_period_desc': 'YEAR',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA'},
#  {'watershed_desc': '',
#   'unit_desc': '$',
#   'year': 2017,
#   'load_time': '2018-02-01 00:00:00.000',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11111)',
#   'county_name': '',
#   'region_desc': '',
#   'county_code': '',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'group_desc': 'CROP TOTALS',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'CV (%)': '9.1',
#   'state_fips_code': '01',
#   'end_code': '00',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'week_ending': '',
#   'Value': '60,335,000',
#   'reference_period_desc': 'YEAR',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'zip_5': '',
#   'country_name': 'UNITED STATES'},
#  {'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'Value': '10,000',
#   'reference_period_desc': 'YEAR',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'week_ending': '',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'freq_desc': 'ANNUAL',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'state_fips_code': '01',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'county_code': '',
#   'CV (%)': '(H)',
#   'group_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11112)',
#   'year': 2017,
#   'unit_desc': '$',
#   'watershed_desc': ''},
#  {'Value': '                 (D)',
#   'reference_period_desc': 'YEAR',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'week_ending': '',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'end_code': '00',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'state_fips_code': '01',
#   'county_code': '',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'group_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'CV (%)': '(D)',
#   'load_time': '2018-02-01 00:00:00.000',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11113)',
#   'county_name': '',
#   'region_desc': '',
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'year': 2017},
#  {'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'county_name': '',
#   'region_desc': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11114)',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'group_desc': 'CROP TOTALS',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'state_name': 'ALABAMA',
#   'CV (%)': '(D)',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'county_code': '',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'state_fips_code': '01',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'end_code': '00',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'Value': '                 (D)',
#   'reference_period_desc': 'YEAR'},
#  {'load_time': '2018-02-01 00:00:00.000',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11115)',
#   'county_name': '',
#   'region_desc': '',
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'year': 2017,
#   'state_fips_code': '01',
#   'county_code': '',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'group_desc': 'CROP TOTALS',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'CV (%)': '18.3',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'end_code': '00',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'reference_period_desc': 'YEAR',
#   'Value': '55,964,000',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'week_ending': ''},
#  {'state_fips_code': '01',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'group_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'CV (%)': '7.3',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11119)',
#   'region_desc': '',
#   'county_name': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'year': 2017,
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'Value': '186,327,000',
#   'reference_period_desc': 'YEAR',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'week_ending': '',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'end_code': '00',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION'},
#  {'domain_desc': 'NAICS CLASSIFICATION',
#   'freq_desc': 'ANNUAL',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'week_ending': '',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'reference_period_desc': 'YEAR',
#   'Value': '52,200,000',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'year': 2017,
#   'unit_desc': '$',
#   'watershed_desc': '',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'load_time': '2018-02-01 00:00:00.000',
#   'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (1112)',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'county_code': '',
#   'CV (%)': '33.0',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'state_name': 'ALABAMA',
#   'group_desc': 'CROP TOTALS',
#   'state_fips_code': '01'},
#  {'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'county_code': '',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'group_desc': 'CROP TOTALS',
#   'CV (%)': '(H)',
#   'state_fips_code': '01',
#   'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'county_name': '',
#   'region_desc': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (111211)',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'reference_period_desc': 'YEAR',
#   'Value': '7,272,000',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'congr_district_code': '',
#   'county_ansi': ''},
#  {'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'freq_desc': 'ANNUAL',
#   'end_code': '00',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'Value': '44,928,000',
#   'reference_period_desc': 'YEAR',
#   'week_ending': '',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'county_name': '',
#   'region_desc': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (111219)',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'load_time': '2018-02-01 00:00:00.000',
#   'year': 2017,
#   'unit_desc': '$',
#   'watershed_desc': '',
#   'state_fips_code': '01',
#   'CV (%)': '17.2',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'state_name': 'ALABAMA',
#   'group_desc': 'CROP TOTALS',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'county_code': ''},
#  {'week_ending': '',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'Value': '15,607,000',
#   'reference_period_desc': 'YEAR',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'freq_desc': 'ANNUAL',
#   'end_code': '00',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'CV (%)': '16.4',
#   'group_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00',
#   'state_alpha': 'AL',
#   'county_code': '',
#   'asd_code': '',
#   'state_fips_code': '01',
#   'year': 2017,
#   'unit_desc': '$',
#   'watershed_desc': '',
#   'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (1113)',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'load_time': '2018-02-01 00:00:00.000'},
#  {'year': 2017,
#   'unit_desc': '$',
#   'watershed_desc': '',
#   'county_name': '',
#   'region_desc': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11131)',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'load_time': '2018-02-01 00:00:00.000',
#   'CV (%)': '(D)',
#   'group_desc': 'CROP TOTALS',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'state_name': 'ALABAMA',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00',
#   'state_alpha': 'AL',
#   'county_code': '',
#   'asd_code': '',
#   'state_fips_code': '01',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'freq_desc': 'ANNUAL',
#   'end_code': '00',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'week_ending': '',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'Value': '                 (D)',
#   'reference_period_desc': 'YEAR'},
#  {'Value': '                 (D)',
#   'reference_period_desc': 'YEAR',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01',
#   'week_ending': '',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'end_code': '00',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'freq_desc': 'ANNUAL',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'state_fips_code': '01',
#   'state_alpha': 'AL',
#   'county_code': '',
#   'asd_code': '',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00',
#   'CV (%)': '(D)',
#   'state_name': 'ALABAMA',
#   'group_desc': 'CROP TOTALS',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'load_time': '2018-02-01 00:00:00.000',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11132)',
#   'county_name': '',
#   'region_desc': '',
#   'unit_desc': '$',
#   'watershed_desc': '',
#   'year': 2017},
#  {'congr_district_code': '',
#   'county_ansi': '',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'end_code': '00',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'freq_desc': 'ANNUAL',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'Value': '15,312,000',
#   'reference_period_desc': 'YEAR',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01',
#   'week_ending': '',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11133)',
#   'county_name': '',
#   'region_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'unit_desc': '$',
#   'watershed_desc': '',
#   'year': 2017,
#   'state_fips_code': '01',
#   'CV (%)': '16.8',
#   'state_name': 'ALABAMA',
#   'group_desc': 'CROP TOTALS',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00'},
#  {'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'reference_period_desc': 'YEAR',
#   'Value': '667,000',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'end_code': '00',
#   'state_fips_code': '01',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'state_name': 'ALABAMA',
#   'group_desc': 'CROP TOTALS',
#   'CV (%)': '15.9',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'county_name': '',
#   'region_desc': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (111331)',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'load_time': '2018-02-01 00:00:00.000',
#   'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': '$'},
#  {'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'county_name': '',
#   'region_desc': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (111332)',
#   'year': 2017,
#   'unit_desc': '$',
#   'watershed_desc': '',
#   'state_fips_code': '01',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00',
#   'asd_code': '',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'CV (%)': '27.0',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'group_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'freq_desc': 'ANNUAL',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'Value': '1,003,000',
#   'reference_period_desc': 'YEAR',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'week_ending': '',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01'},
#  {'domaincat_desc': 'NAICS CLASSIFICATION: (111333)',
#   'region_desc': '',
#   'county_name': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'unit_desc': '$',
#   'watershed_desc': '',
#   'year': 2017,
#   'state_fips_code': '01',
#   'CV (%)': '26.5',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'group_desc': 'CROP TOTALS',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'end_code': '00',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'freq_desc': 'ANNUAL',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'Value': '339,000',
#   'reference_period_desc': 'YEAR',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01',
#   'week_ending': '',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $'},
#  {'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'reference_period_desc': 'YEAR',
#   'Value': '2,683,000',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'week_ending': '',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'freq_desc': 'ANNUAL',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'state_fips_code': '01',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00',
#   'county_code': '',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'CV (%)': '19.0',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'state_name': 'ALABAMA',
#   'group_desc': 'CROP TOTALS',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'load_time': '2018-02-01 00:00:00.000',
#   'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (111334)',
#   'year': 2017,
#   'unit_desc': '$',
#   'watershed_desc': ''},
#  {'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'end_code': '00',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'freq_desc': 'ANNUAL',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01',
#   'week_ending': '',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'Value': '5,385,000',
#   'reference_period_desc': 'YEAR',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'unit_desc': '$',
#   'watershed_desc': '',
#   'year': 2017,
#   'domaincat_desc': 'NAICS CLASSIFICATION: (111335)',
#   'region_desc': '',
#   'county_name': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'CV (%)': '23.0',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'group_desc': 'CROP TOTALS',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'county_code': '',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00',
#   'state_fips_code': '01'},
#  {'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'reference_period_desc': 'YEAR',
#   'Value': '375,000',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'end_code': '00',
#   'state_fips_code': '01',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'group_desc': 'CROP TOTALS',
#   'CV (%)': '18.0',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (111336)',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'load_time': '2018-02-01 00:00:00.000',
#   'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': '$'},
#  {'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'load_time': '2018-02-01 00:00:00.000',
#   'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (111339)',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'state_alpha': 'AL',
#   'county_code': '',
#   'asd_code': '',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'group_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'CV (%)': '45.1',
#   'state_fips_code': '01',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'reference_period_desc': 'YEAR',
#   'Value': '4,860,000',
#   'country_name': 'UNITED STATES',
#   'zip_5': ''},
#  {'unit_desc': '$',
#   'watershed_desc': '',
#   'year': 2017,
#   'domaincat_desc': 'NAICS CLASSIFICATION: (1114)',
#   'region_desc': '',
#   'county_name': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'CV (%)': '4.0',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'group_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'county_code': '',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00',
#   'state_fips_code': '01',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'end_code': '00',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'freq_desc': 'ANNUAL',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01',
#   'week_ending': '',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'reference_period_desc': 'YEAR',
#   'Value': '295,480,000',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000'},
#  {'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'week_ending': '',
#   'reference_period_desc': 'YEAR',
#   'Value': '2,418,000',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'end_code': '00',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'state_alpha': 'AL',
#   'county_code': '',
#   'asd_code': '',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'group_desc': 'CROP TOTALS',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'CV (%)': '(H)',
#   'state_fips_code': '01',
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'year': 2017,
#   'load_time': '2018-02-01 00:00:00.000',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11141)',
#   'region_desc': '',
#   'county_name': ''},
#  {'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11142)',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'group_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'CV (%)': '3.6',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'state_fips_code': '01',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'end_code': '00',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'Value': '293,062,000',
#   'reference_period_desc': 'YEAR'},
#  {'state_fips_code': '01',
#   'CV (%)': '7.0',
#   'state_name': 'ALABAMA',
#   'group_desc': 'CROP TOTALS',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'county_code': '',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (111421)',
#   'region_desc': '',
#   'county_name': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'unit_desc': '$',
#   'watershed_desc': '',
#   'year': 2017,
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'Value': '160,728,000',
#   'reference_period_desc': 'YEAR',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01',
#   'week_ending': '',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'end_code': '00',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'freq_desc': 'ANNUAL'},
#  {'county_name': '',
#   'region_desc': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (111422)',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'load_time': '2018-02-01 00:00:00.000',
#   'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'state_fips_code': '01',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'group_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'CV (%)': '5.5',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'end_code': '00',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'reference_period_desc': 'YEAR',
#   'Value': '132,334,000',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000'},
#  {'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'reference_period_desc': 'YEAR',
#   'Value': '464,823,000',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'end_code': '00',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'group_desc': 'CROP TOTALS',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'state_name': 'ALABAMA',
#   'CV (%)': '5.0',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'state_alpha': 'AL',
#   'county_code': '',
#   'asd_code': '',
#   'state_fips_code': '01',
#   'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (1119)',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'load_time': '2018-02-01 00:00:00.000'},
#  {'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'Value': '192,144,000',
#   'reference_period_desc': 'YEAR',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'week_ending': '',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'end_code': '00',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'state_fips_code': '01',
#   'group_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'CV (%)': '18.0',
#   'asd_code': '',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11192)',
#   'county_name': '',
#   'region_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'year': 2017},
#  {'state_fips_code': '01',
#   'group_desc': 'CROP TOTALS',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'state_name': 'ALABAMA',
#   'CV (%)': '8.4',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'county_code': '',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11194)',
#   'region_desc': '',
#   'county_name': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'year': 2017,
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'reference_period_desc': 'YEAR',
#   'Value': '61,375,000',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'week_ending': '',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'end_code': '00',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION'},
#  {'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'reference_period_desc': 'YEAR',
#   'Value': '211,304,000',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'state_fips_code': '01',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'state_name': 'ALABAMA',
#   'group_desc': 'CROP TOTALS',
#   'CV (%)': '8.4',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11199)',
#   'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': '$'},
#  {'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'state_ansi': '01',
#   'week_ending': '',
#   'Value': '80,935,000',
#   'reference_period_desc': 'YEAR',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'end_code': '00',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'freq_desc': 'ANNUAL',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'county_code': '',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00',
#   'CV (%)': '8.5',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'group_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'state_fips_code': '01',
#   'unit_desc': '$',
#   'watershed_desc': '',
#   'year': 2017,
#   'load_time': '2018-02-01 00:00:00.000',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (112)',
#   'county_name': '',
#   'region_desc': ''},
#  {'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'reference_period_desc': 'YEAR',
#   'Value': '33,572,000',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'county_name': '',
#   'region_desc': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (1121)',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'group_desc': 'CROP TOTALS',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'state_name': 'ALABAMA',
#   'CV (%)': '16.1',
#   'state_fips_code': '01'},
#  {'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'reference_period_desc': 'YEAR',
#   'Value': '32,990,000',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'end_code': '00',
#   'state_fips_code': '01',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'state_name': 'ALABAMA',
#   'group_desc': 'CROP TOTALS',
#   'CV (%)': '16.3',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'state_alpha': 'AL',
#   'county_code': '',
#   'asd_code': '',
#   'county_name': '',
#   'region_desc': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11211)',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'load_time': '2018-02-01 00:00:00.000',
#   'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': '$'},
#  {'domaincat_desc': 'NAICS CLASSIFICATION: (112111)',
#   'county_name': '',
#   'region_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'year': 2017,
#   'state_fips_code': '01',
#   'state_name': 'ALABAMA',
#   'group_desc': 'CROP TOTALS',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'CV (%)': '16.3',
#   'county_code': '',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'end_code': '00',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'reference_period_desc': 'YEAR',
#   'Value': '32,990,000',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'week_ending': '',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000'},
#  {'county_ansi': '',
#   'congr_district_code': '',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'end_code': '00',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'reference_period_desc': 'YEAR',
#   'Value': '583,000',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'week_ending': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11212)',
#   'region_desc': '',
#   'county_name': '',
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'year': 2017,
#   'state_fips_code': '01',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'group_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'CV (%)': '46.5'},
#  {'load_time': '2018-02-01 00:00:00.000',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (1122)',
#   'region_desc': '',
#   'county_name': '',
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'year': 2017,
#   'state_fips_code': '01',
#   'asd_code': '',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'state_name': 'ALABAMA',
#   'group_desc': 'CROP TOTALS',
#   'CV (%)': '80.2',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'end_code': '00',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'Value': '358,000',
#   'reference_period_desc': 'YEAR',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'week_ending': ''},
#  {'county_ansi': '',
#   'congr_district_code': '',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'end_code': '00',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'reference_period_desc': 'YEAR',
#   'Value': '42,552,000',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'week_ending': '',
#   'watershed_code': '00000000',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (1123)',
#   'county_name': '',
#   'region_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'statisticcat_desc': 'SALES',
#   'asd_desc': '',
#   'watershed_desc': '',
#   'unit_desc': '$',
#   'year': 2017,
#   'state_fips_code': '01',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'group_desc': 'CROP TOTALS',
#   'state_name': 'ALABAMA',
#   'CV (%)': '4.8',
#   'county_code': '',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS'},
#  {'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'reference_period_desc': 'YEAR',
#   'Value': '                 (D)',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'short_desc': 'CROP TOTALS - SALES, MEASURED IN $',
#   'watershed_code': '00000000',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'state_fips_code': '01',
#   'begin_code': '00',
#   'commodity_desc': 'CROP TOTALS',
#   'county_code': '',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'group_desc': 'CROP TOTALS',
#   'CV (%)': '(D)',
#   'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'load_time': '2018-02-01 00:00:00.000',
#   'county_name': '',
#   'region_desc': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11231)',
#   'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': '$'},
#  {'asd_desc': '',
#   'statisticcat_desc': 'SALES',
#   'load_time': '2018-02-01 00:00:00.000',
#   'county_name': '',
#   'region_desc': '',
#   'domaincat_desc': 'NAICS CLASSIFICATION: (11232)',
#   'year': 2017,
#   'unit_desc': '$',
#   'watershed_desc': '',
#   'state_fips_code': '01',
#   'commodity_desc': 'CROP TOTALS',
#   'begin_code': '00',
#   'asd_code': '',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'CV (%)': '5.1',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'group_desc': 'CROP TOTALS',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'domain_desc': 'NAICS CLASSIFICATION',
#   'freq_desc': 'ANNUAL',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'country_code': '9000',
# ...
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'Value': '3',
#   'reference_period_desc': 'YEAR',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'short_desc': 'CORN, GRAIN, IRRIGATED - OPERATIONS WITH AREA HARVESTED',
#   'watershed_code': '00000000',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'IRRIGATED'},
#  {'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'reference_period_desc': 'YEAR',
#   'Value': '38',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'watershed_code': '00000000',
#   'short_desc': 'CORN, GRAIN, IRRIGATED - OPERATIONS WITH AREA HARVESTED',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'IRRIGATED',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'AREA OPERATED',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'state_fips_code': '01',
#   'begin_code': '00',
#   'commodity_desc': 'CORN',
#   'county_code': '',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'group_desc': 'FIELD CROPS',
#   'util_practice_desc': 'GRAIN',
#   'state_name': 'ALABAMA',
#   'CV (%)': '27.5',
#   'asd_desc': '',
#   'statisticcat_desc': 'AREA HARVESTED',
#   'load_time': '2018-02-01 00:00:00.000',
#   'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'AREA OPERATED: (1,000 TO 1,999 ACRES)',
#   'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': 'OPERATIONS'},
#  {'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'Value': '11',
#   'reference_period_desc': 'YEAR',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'watershed_code': '00000000',
#   'short_desc': 'CORN, GRAIN, IRRIGATED - OPERATIONS WITH AREA HARVESTED',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'IRRIGATED',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'AREA OPERATED',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'state_fips_code': '01',
#   'begin_code': '00',
#   'commodity_desc': 'CORN',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'util_practice_desc': 'GRAIN',
#   'state_name': 'ALABAMA',
#   'group_desc': 'FIELD CROPS',
#   'CV (%)': '(H)',
#   'asd_desc': '',
#   'statisticcat_desc': 'AREA HARVESTED',
#   'load_time': '2018-02-01 00:00:00.000',
#   'county_name': '',
#   'region_desc': '',
#   'domaincat_desc': 'AREA OPERATED: (10.0 TO 49.9 ACRES)',
#   'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': 'OPERATIONS'},
#  {'watershed_code': '00000000',
#   'short_desc': 'CORN, GRAIN, IRRIGATED - OPERATIONS WITH AREA HARVESTED',
#   'week_ending': '',
#   'prodn_practice_desc': 'IRRIGATED',
#   'state_ansi': '01',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'reference_period_desc': 'YEAR',
#   'Value': '7',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'domain_desc': 'AREA OPERATED',
#   'freq_desc': 'ANNUAL',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'commodity_desc': 'CORN',
#   'begin_code': '00',
#   'asd_code': '',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'CV (%)': '(H)',
#   'group_desc': 'FIELD CROPS',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'GRAIN',
#   'state_fips_code': '01',
#   'year': 2017,
#   'unit_desc': 'OPERATIONS',
#   'watershed_desc': '',
#   'asd_desc': '',
#   'statisticcat_desc': 'AREA HARVESTED',
#   'load_time': '2018-02-01 00:00:00.000',
#   'county_name': '',
#   'region_desc': '',
#   'domaincat_desc': 'AREA OPERATED: (100 TO 139 ACRES)'},
#  {'CV (%)': '12.3',
#   'state_name': 'ALABAMA',
#   'group_desc': 'FIELD CROPS',
#   'util_practice_desc': 'GRAIN',
#   'asd_code': '',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'commodity_desc': 'CORN',
#   'begin_code': '00',
#   'state_fips_code': '01',
#   'unit_desc': 'OPERATIONS',
#   'watershed_desc': '',
#   'year': 2017,
#   'domaincat_desc': 'AREA OPERATED: (2,000 OR MORE ACRES)',
#   'region_desc': '',
#   'county_name': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'asd_desc': '',
#   'statisticcat_desc': 'AREA HARVESTED',
#   'prodn_practice_desc': 'IRRIGATED',
#   'state_ansi': '01',
#   'week_ending': '',
#   'short_desc': 'CORN, GRAIN, IRRIGATED - OPERATIONS WITH AREA HARVESTED',
#   'watershed_code': '00000000',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'Value': '47',
#   'reference_period_desc': 'YEAR',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'end_code': '00',
#   'domain_desc': 'AREA OPERATED',
#   'freq_desc': 'ANNUAL',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS'},
#  {'county_ansi': '',
#   'congr_district_code': '',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'end_code': '00',
#   'domain_desc': 'AREA OPERATED',
#   'freq_desc': 'ANNUAL',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'reference_period_desc': 'YEAR',
#   'Value': '13',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'prodn_practice_desc': 'IRRIGATED',
#   'state_ansi': '01',
#   'week_ending': '',
#   'watershed_code': '00000000',
#   'short_desc': 'CORN, GRAIN, IRRIGATED - OPERATIONS WITH AREA HARVESTED',
#   'domaincat_desc': 'AREA OPERATED: (260 TO 499 ACRES)',
#   'county_name': '',
#   'region_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'statisticcat_desc': 'AREA HARVESTED',
#   'asd_desc': '',
#   'unit_desc': 'OPERATIONS',
#   'watershed_desc': '',
#   'year': 2017,
#   'state_fips_code': '01',
#   'CV (%)': '(H)',
#   'util_practice_desc': 'GRAIN',
#   'state_name': 'ALABAMA',
#   'group_desc': 'FIELD CROPS',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'commodity_desc': 'CORN',
#   'begin_code': '00'},
#  {'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'end_code': '00',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'AREA OPERATED',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'IRRIGATED',
#   'week_ending': '',
#   'short_desc': 'CORN, GRAIN, IRRIGATED - OPERATIONS WITH AREA HARVESTED',
#   'watershed_code': '00000000',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'Value': '2',
#   'reference_period_desc': 'YEAR',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'watershed_desc': '',
#   'unit_desc': 'OPERATIONS',
#   'year': 2017,
#   'domaincat_desc': 'AREA OPERATED: (50.0 TO 69.9 ACRES)',
#   'county_name': '',
#   'region_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'statisticcat_desc': 'AREA HARVESTED',
#   'asd_desc': '',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'GRAIN',
#   'group_desc': 'FIELD CROPS',
#   'CV (%)': '1.9',
#   'asd_code': '',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'begin_code': '00',
#   'commodity_desc': 'CORN',
#   'state_fips_code': '01'},
#  {'state_fips_code': '01',
#   'commodity_desc': 'CORN',
#   'begin_code': '00',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'CV (%)': '55.3',
#   'util_practice_desc': 'GRAIN',
#   'state_name': 'ALABAMA',
#   'group_desc': 'FIELD CROPS',
#   'asd_desc': '',
#   'statisticcat_desc': 'AREA HARVESTED',
#   'load_time': '2018-02-01 00:00:00.000',
#   'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'AREA OPERATED: (500 TO 999 ACRES)',
#   'year': 2017,
#   'unit_desc': 'OPERATIONS',
#   'watershed_desc': '',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'Value': '21',
#   'reference_period_desc': 'YEAR',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'short_desc': 'CORN, GRAIN, IRRIGATED - OPERATIONS WITH AREA HARVESTED',
#   'watershed_code': '00000000',
#   'week_ending': '',
#   'prodn_practice_desc': 'IRRIGATED',
#   'state_ansi': '01',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'domain_desc': 'AREA OPERATED',
#   'freq_desc': 'ANNUAL',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA'},
#  {'state_fips_code': '01',
#   'group_desc': 'FIELD CROPS',
#   'util_practice_desc': 'GRAIN',
#   'state_name': 'ALABAMA',
#   'CV (%)': '3.5',
#   'begin_code': '00',
#   'commodity_desc': 'CORN',
#   'county_code': '',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'AREA OPERATED: (70.0 TO 99.9 ACRES)',
#   'statisticcat_desc': 'AREA HARVESTED',
#   'asd_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': 'OPERATIONS',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'reference_period_desc': 'YEAR',
#   'Value': '2',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'IRRIGATED',
#   'watershed_code': '00000000',
#   'short_desc': 'CORN, GRAIN, IRRIGATED - OPERATIONS WITH AREA HARVESTED',
#   'source_desc': 'CENSUS',
#   'sector_desc': 'CROPS',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'AREA OPERATED',
#   'end_code': '00'},
#  {'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'ECONOMIC CLASS: (1,000 TO 2,499 $)',
#   'statisticcat_desc': 'AREA HARVESTED',
#   'asd_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'year': 2017,
#   'unit_desc': 'OPERATIONS',
#   'watershed_desc': '',
#   'state_fips_code': '01',
#   'CV (%)': '(H)',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'GRAIN',
#   'group_desc': 'FIELD CROPS',
#   'commodity_desc': 'CORN',
#   'begin_code': '00',
#   'county_code': '',
#   'asd_code': '',
#   'state_alpha': 'AL',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'domain_desc': 'ECONOMIC CLASS',
#   'freq_desc': 'ANNUAL',
#   'end_code': '00',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'Value': '6',
#   'reference_period_desc': 'YEAR',
#   'week_ending': '',
#   'prodn_practice_desc': 'IRRIGATED',
#   'state_ansi': '01',
#   'short_desc': 'CORN, GRAIN, IRRIGATED - OPERATIONS WITH AREA HARVESTED',
#   'watershed_code': '00000000'},
#  {'CV (%)': '3.1',
#   'util_practice_desc': 'GRAIN',
#   'group_desc': 'FIELD CROPS',
#   'state_name': 'ALABAMA',
#   'commodity_desc': 'CORN',
#   'begin_code': '00',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'state_fips_code': '01',
#   'year': 2017,
#   'unit_desc': 'OPERATIONS',
#   'watershed_desc': '',
#   'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'ECONOMIC CLASS: (1,000,000 OR MORE $)',
#   'statisticcat_desc': 'AREA HARVESTED',
#   'asd_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'week_ending': '',
#   'prodn_practice_desc': 'IRRIGATED',
#   'state_ansi': '01',
#   'short_desc': 'CORN, GRAIN, IRRIGATED - OPERATIONS WITH AREA HARVESTED',
#   'watershed_code': '00000000',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'reference_period_desc': 'YEAR',
#   'Value': '55',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'domain_desc': 'ECONOMIC CLASS',
#   'freq_desc': 'ANNUAL',
#   'end_code': '00',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'county_ansi': '',
#   'congr_district_code': ''},
#  {'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'ECONOMIC CLASS',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'reference_period_desc': 'YEAR',
#   'Value': '3',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'watershed_code': '00000000',
#   'short_desc': 'CORN, GRAIN, IRRIGATED - OPERATIONS WITH AREA HARVESTED',
#   'week_ending': '',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'IRRIGATED',
#   'statisticcat_desc': 'AREA HARVESTED',
#   'asd_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'ECONOMIC CLASS: (10,000 TO 24,999 $)',
#   'year': 2017,
#   'watershed_desc': '',
#   'unit_desc': 'OPERATIONS',
#   'state_fips_code': '01',
#   'begin_code': '00',
#   'commodity_desc': 'CORN',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'county_code': '',
#   'group_desc': 'FIELD CROPS',
#   'util_practice_desc': 'GRAIN',
#   'state_name': 'ALABAMA',
#   'CV (%)': '2.3'},
#  {'group_desc': 'FIELD CROPS',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'GRAIN',
#   'CV (%)': '(H)',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'begin_code': '00',
#   'commodity_desc': 'CORN',
#   'state_fips_code': '01',
#   'watershed_desc': '',
#   'unit_desc': 'OPERATIONS',
#   'year': 2017,
#   'domaincat_desc': 'ECONOMIC CLASS: (100,000 TO 249,999 $)',
#   'county_name': '',
#   'region_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'asd_desc': '',
#   'statisticcat_desc': 'AREA HARVESTED',
#   'state_ansi': '01',
#   'prodn_practice_desc': 'IRRIGATED',
#   'week_ending': '',
#   'watershed_code': '00000000',
#   'short_desc': 'CORN, GRAIN, IRRIGATED - OPERATIONS WITH AREA HARVESTED',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'reference_period_desc': 'YEAR',
#   'Value': '14',
#   'agg_level_desc': 'STATE',
#   'country_code': '9000',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'end_code': '00',
#   'freq_desc': 'ANNUAL',
#   'domain_desc': 'ECONOMIC CLASS',
#   'county_ansi': '',
#   'congr_district_code': '',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS'},
#  {'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'domain_desc': 'ECONOMIC CLASS',
#   'freq_desc': 'ANNUAL',
#   'end_code': '00',
#   'class_desc': 'ALL CLASSES',
#   'location_desc': 'ALABAMA',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'Value': '9',
#   'reference_period_desc': 'YEAR',
#   'country_name': 'UNITED STATES',
#   'zip_5': '',
#   'short_desc': 'CORN, GRAIN, IRRIGATED - OPERATIONS WITH AREA HARVESTED',
#   'watershed_code': '00000000',
#   'week_ending': '',
#   'prodn_practice_desc': 'IRRIGATED',
#   'state_ansi': '01',
#   'statisticcat_desc': 'AREA HARVESTED',
#   'asd_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'region_desc': '',
#   'county_name': '',
#   'domaincat_desc': 'ECONOMIC CLASS: (25,000 TO 49,999 $)',
#   'year': 2017,
#   'unit_desc': 'OPERATIONS',
#   'watershed_desc': '',
#   'state_fips_code': '01',
#   'commodity_desc': 'CORN',
#   'begin_code': '00',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'asd_code': '',
#   'CV (%)': '(H)',
#   'util_practice_desc': 'GRAIN',
#   'state_name': 'ALABAMA',
#   'group_desc': 'FIELD CROPS'},
#  {'prodn_practice_desc': 'IRRIGATED',
#   'state_ansi': '01',
#   'week_ending': '',
#   'short_desc': 'CORN, GRAIN, IRRIGATED - OPERATIONS WITH AREA HARVESTED',
#   'watershed_code': '00000000',
#   'zip_5': '',
#   'country_name': 'UNITED STATES',
#   'Value': '10',
#   'reference_period_desc': 'YEAR',
#   'country_code': '9000',
#   'agg_level_desc': 'STATE',
#   'location_desc': 'ALABAMA',
#   'class_desc': 'ALL CLASSES',
#   'end_code': '00',
#   'domain_desc': 'ECONOMIC CLASS',
#   'freq_desc': 'ANNUAL',
#   'congr_district_code': '',
#   'county_ansi': '',
#   'sector_desc': 'CROPS',
#   'source_desc': 'CENSUS',
#   'CV (%)': '71.4',
#   'state_name': 'ALABAMA',
#   'util_practice_desc': 'GRAIN',
#   'group_desc': 'FIELD CROPS',
#   'asd_code': '',
#   'county_code': '',
#   'state_alpha': 'AL',
#   'commodity_desc': 'CORN',
#   'begin_code': '00',
#   'state_fips_code': '01',
#   'unit_desc': 'OPERATIONS',
#   'watershed_desc': '',
#   'year': 2017,
#   'domaincat_desc': 'ECONOMIC CLASS: (250,000 TO 499,999 $)',
#   'county_name': '',
#   'region_desc': '',
#   'load_time': '2018-02-01 00:00:00.000',
#   'asd_desc': '',
#   'statisticcat_desc': 'AREA HARVESTED'},
#  ...]

# %%
#This makes a usable DF. Need to create loop to run all 50 indexes
useable = pd.json_normalize(res_2017[0]['data'])

# %%
total_2017df = pd.DataFrame()  # Initialize an empty DataFrame to store the merged results

for x in range(50):
    df = pd.json_normalize(res_2017[x]['data'])
    total_2017df = pd.concat([total_2017df, df], ignore_index=True)

# %%
call2 = "https://quickstats.nass.usda.gov/api/api_GET/?key=" + api_key +"&source_desc=CENSUS&sector_desc=CROPS&agg_level_desc=STATE&year=2012&state_alpha="

res_2012 = []
states = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'IA','ME', 'MD','MA', 'MI','MN', 'MS','MO', 'MT','NE','NV','NH', 'NJ','NM', 'NY','NC', 'ND','OH', 'OK','OR', 'PA','RI','SC','SD', 'TN','TX','UT','VT','VA','WA','WV','WI','WY']  # List of states to iterate over

for state in states:
    endpoint2 = call2 + state  
    result = requests.get(endpoint2)  
    res_2012.append(result.json())  
    print(result)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
pd.json_normalize(res_2012[0]['data'])
# Out:
#                                          domaincat_desc county_name  \
# 0                 IRRIGATION STATUS: (ANY ON OPERATION)
# 1     IRRIGATION STATUS: (HARVESTED CROPLAND IS ENTI...
# 2                IRRIGATION STATUS: (NONE ON OPERATION)
# 3                           NAICS CLASSIFICATION: (111)
# 4                          NAICS CLASSIFICATION: (1111)
# ...                                                 ...         ...
# 9870                                      NOT SPECIFIED
# 9871                                      NOT SPECIFIED
# 9872                                      NOT SPECIFIED
# 9873                                      NOT SPECIFIED
# 9874                                      NOT SPECIFIED
#
#      region_desc                load_time asd_desc statisticcat_desc  \
# 0                 2012-12-31 00:00:00.000                      SALES
# 1                 2012-12-31 00:00:00.000                      SALES
# 2                 2012-12-31 00:00:00.000                      SALES
# 3                 2012-12-31 00:00:00.000                      SALES
# 4                 2012-12-31 00:00:00.000                      SALES
# ...          ...                      ...      ...               ...
# 9870              2012-12-31 00:00:00.000             AREA HARVESTED
# 9871              2012-12-31 00:00:00.000             AREA HARVESTED
# 9872              2012-12-31 00:00:00.000             AREA HARVESTED
# 9873              2012-12-31 00:00:00.000             AREA HARVESTED
# 9874              2012-12-31 00:00:00.000             AREA HARVESTED
#
#        unit_desc watershed_desc  year state_fips_code  ...   country_name  \
# 0              $                 2012              01  ...  UNITED STATES
# 1              $                 2012              01  ...  UNITED STATES
# 2              $                 2012              01  ...  UNITED STATES
# 3              $                 2012              01  ...  UNITED STATES
# 4              $                 2012              01  ...  UNITED STATES
# ...          ...            ...   ...             ...  ...            ...
# 9870  OPERATIONS                 2012              01  ...  UNITED STATES
# 9871       ACRES                 2012              01  ...  UNITED STATES
# 9872  OPERATIONS                 2012              01  ...  UNITED STATES
# 9873       ACRES                 2012              01  ...  UNITED STATES
# 9874  OPERATIONS                 2012              01  ...  UNITED STATES
#
#      reference_period_desc          Value country_code agg_level_desc  \
# 0                     YEAR    563,265,000         9000          STATE
# 1                     YEAR    184,070,000         9000          STATE
# 2                     YEAR    751,706,000         9000          STATE
# 3                     YEAR  1,241,618,000         9000          STATE
# 4                     YEAR    396,493,000         9000          STATE
# ...                    ...            ...          ...            ...
# 9870                  YEAR             62         9000          STATE
# 9871                  YEAR            148         9000          STATE
# 9872                  YEAR             57         9000          STATE
# 9873                  YEAR              6         9000          STATE
# 9874                  YEAR              7         9000          STATE
#
#            prodn_practice_desc state_ansi week_ending  \
# 0     ALL PRODUCTION PRACTICES         01
# 1     ALL PRODUCTION PRACTICES         01
# 2     ALL PRODUCTION PRACTICES         01
# 3     ALL PRODUCTION PRACTICES         01
# 4     ALL PRODUCTION PRACTICES         01
# ...                        ...        ...         ...
# 9870  ALL PRODUCTION PRACTICES         01
# 9871  ALL PRODUCTION PRACTICES         01
# 9872  ALL PRODUCTION PRACTICES         01
# 9873  ALL PRODUCTION PRACTICES         01
# 9874  ALL PRODUCTION PRACTICES         01
#
#                                              short_desc watershed_code
# 0                    CROP TOTALS - SALES, MEASURED IN $       00000000
# 1                    CROP TOTALS - SALES, MEASURED IN $       00000000
# 2                    CROP TOTALS - SALES, MEASURED IN $       00000000
# 3                    CROP TOTALS - SALES, MEASURED IN $       00000000
# 4                    CROP TOTALS - SALES, MEASURED IN $       00000000
# ...                                                 ...            ...
# 9870  VEGETABLES, OTHER - OPERATIONS WITH AREA HARVE...       00000000
# 9871  VEGETABLES, OTHER, FRESH MARKET - ACRES HARVESTED       00000000
# 9872  VEGETABLES, OTHER, FRESH MARKET - OPERATIONS W...       00000000
# 9873    VEGETABLES, OTHER, PROCESSING - ACRES HARVESTED       00000000
# 9874  VEGETABLES, OTHER, PROCESSING - OPERATIONS WIT...       00000000
#
# [9875 rows x 39 columns]

# %%
total_2012df = pd.DataFrame()  # Initialize an empty DataFrame to store the merged results

for x in range(50):
    df = pd.json_normalize(res_2012[x]['data'])
    total_2012df = pd.concat([total_2012df, df], ignore_index=True)

# %%
total_2012df
# Out:
#                                            domaincat_desc county_name  \
# 0                   IRRIGATION STATUS: (ANY ON OPERATION)
# 1       IRRIGATION STATUS: (HARVESTED CROPLAND IS ENTI...
# 2                  IRRIGATION STATUS: (NONE ON OPERATION)
# 3                             NAICS CLASSIFICATION: (111)
# 4                            NAICS CLASSIFICATION: (1111)
# ...                                                   ...         ...
# 462462                                      NOT SPECIFIED
# 462463                                      NOT SPECIFIED
# 462464                                      NOT SPECIFIED
# 462465                                      NOT SPECIFIED
# 462466                                      NOT SPECIFIED
#
#        region_desc                load_time asd_desc statisticcat_desc  \
# 0                   2012-12-31 00:00:00.000                      SALES
# 1                   2012-12-31 00:00:00.000                      SALES
# 2                   2012-12-31 00:00:00.000                      SALES
# 3                   2012-12-31 00:00:00.000                      SALES
# 4                   2012-12-31 00:00:00.000                      SALES
# ...            ...                      ...      ...               ...
# 462462              2012-12-31 00:00:00.000                      SALES
# 462463              2012-12-31 00:00:00.000             AREA HARVESTED
# 462464              2012-12-31 00:00:00.000             AREA HARVESTED
# 462465              2012-12-31 00:00:00.000             AREA HARVESTED
# 462466              2012-12-31 00:00:00.000             AREA HARVESTED
#
#                 unit_desc watershed_desc  year state_fips_code  ...  \
# 0                       $                 2012              01  ...
# 1                       $                 2012              01  ...
# 2                       $                 2012              01  ...
# 3                       $                 2012              01  ...
# 4                       $                 2012              01  ...
# ...                   ...            ...   ...             ...  ...
# 462462  PCT OF FARM SALES                 2012              56  ...
# 462463              ACRES                 2012              56  ...
# 462464         OPERATIONS                 2012              56  ...
# 462465              ACRES                 2012              56  ...
# 462466         OPERATIONS                 2012              56  ...
#
#          country_name reference_period_desc          Value country_code  \
# 0       UNITED STATES                  YEAR    563,265,000         9000
# 1       UNITED STATES                  YEAR    184,070,000         9000
# 2       UNITED STATES                  YEAR    751,706,000         9000
# 3       UNITED STATES                  YEAR  1,241,618,000         9000
# 4       UNITED STATES                  YEAR    396,493,000         9000
# ...               ...                   ...            ...          ...
# 462462  UNITED STATES                  YEAR            0.2         9000
# 462463  UNITED STATES                  YEAR              1         9000
# 462464  UNITED STATES                  YEAR              3         9000
# 462465  UNITED STATES                  YEAR              1         9000
# 462466  UNITED STATES                  YEAR              3         9000
#
#        agg_level_desc       prodn_practice_desc state_ansi week_ending  \
# 0               STATE  ALL PRODUCTION PRACTICES         01
# 1               STATE  ALL PRODUCTION PRACTICES         01
# 2               STATE  ALL PRODUCTION PRACTICES         01
# 3               STATE  ALL PRODUCTION PRACTICES         01
# 4               STATE  ALL PRODUCTION PRACTICES         01
# ...               ...                       ...        ...         ...
# 462462          STATE               IN THE OPEN         56
# 462463          STATE  ALL PRODUCTION PRACTICES         56
# 462464          STATE  ALL PRODUCTION PRACTICES         56
# 462465          STATE  ALL PRODUCTION PRACTICES         56
# 462466          STATE  ALL PRODUCTION PRACTICES         56
#
#                                                short_desc watershed_code
# 0                      CROP TOTALS - SALES, MEASURED IN $       00000000
# 1                      CROP TOTALS - SALES, MEASURED IN $       00000000
# 2                      CROP TOTALS - SALES, MEASURED IN $       00000000
# 3                      CROP TOTALS - SALES, MEASURED IN $       00000000
# 4                      CROP TOTALS - SALES, MEASURED IN $       00000000
# ...                                                   ...            ...
# 462462  VEGETABLE TOTALS, INCL SEEDS & TRANSPLANTS, IN...       00000000
# 462463                VEGETABLES, OTHER - ACRES HARVESTED       00000000
# 462464  VEGETABLES, OTHER - OPERATIONS WITH AREA HARVE...       00000000
# 462465  VEGETABLES, OTHER, FRESH MARKET - ACRES HARVESTED       00000000
# 462466  VEGETABLES, OTHER, FRESH MARKET - OPERATIONS W...       00000000
#
# [462467 rows x 39 columns]

# %%
call3 = "https://quickstats.nass.usda.gov/api/api_GET/?key=" + api_key + "&source_desc=CENSUS&sector_desc=CROPS&agg_level_desc=STATE&year=2007&state_alpha="

res_2007 = []
states = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'IA','ME', 'MD','MA', 'MI','MN', 'MS','MO', 'MT','NE','NV','NH', 'NJ','NM', 'NY','NC', 'ND','OH', 'OK','OR', 'PA','RI','SC','SD', 'TN','TX','UT','VT','VA','WA','WV','WI','WY']  # List of states to iterate over

for state in states:
    endpoint3 = call3 + state  
    result = requests.get(endpoint3)  
    res_2007.append(result.json())  
    print(result)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
total_2007df = pd.DataFrame()  # Initialize an empty DataFrame to store the merged results

for x in range(50):
    df = pd.json_normalize(res_2007[x]['data'])
    total_2007df = pd.concat([total_2007df, df], ignore_index=True)

# %%
total_2007df
# Out:
#        county_name                 Value watershed_code begin_code asd_code  \
# 0                            381,953,000       00000000         00
# 1                            219,105,000       00000000         00
# 2                            295,034,000       00000000         00
# 3                            638,606,000       00000000         00
# 4                             97,021,000       00000000         00
# ...            ...                   ...            ...        ...      ...
# 110725                               0.3       00000000         00
# 110726                               (D)       00000000         00
# 110727                                 1       00000000         00
# 110728                               (D)       00000000         00
# 110729                                 1       00000000         00
#
#                       class_desc     commodity_desc  \
# 0                    ALL CLASSES        CROP TOTALS
# 1                    ALL CLASSES        CROP TOTALS
# 2                    ALL CLASSES        CROP TOTALS
# 3                    ALL CLASSES        CROP TOTALS
# 4                    ALL CLASSES        CROP TOTALS
# ...                          ...                ...
# 110725  INCL SEEDS & TRANSPLANTS   VEGETABLE TOTALS
# 110726               ALL CLASSES  VEGETABLES, OTHER
# 110727               ALL CLASSES  VEGETABLES, OTHER
# 110728               ALL CLASSES  VEGETABLES, OTHER
# 110729               ALL CLASSES  VEGETABLES, OTHER
#
#                                                short_desc statisticcat_desc  \
# 0                      CROP TOTALS - SALES, MEASURED IN $             SALES
# 1                      CROP TOTALS - SALES, MEASURED IN $             SALES
# 2                      CROP TOTALS - SALES, MEASURED IN $             SALES
# 3                      CROP TOTALS - SALES, MEASURED IN $             SALES
# 4                      CROP TOTALS - SALES, MEASURED IN $             SALES
# ...                                                   ...               ...
# 110725  VEGETABLE TOTALS, INCL SEEDS & TRANSPLANTS, IN...             SALES
# 110726                VEGETABLES, OTHER - ACRES HARVESTED    AREA HARVESTED
# 110727  VEGETABLES, OTHER - OPERATIONS WITH AREA HARVE...    AREA HARVESTED
# 110728  VEGETABLES, OTHER, FRESH MARKET - ACRES HARVESTED    AREA HARVESTED
# 110729  VEGETABLES, OTHER, FRESH MARKET - OPERATIONS W...    AREA HARVESTED
#
#                       load_time  ... freq_desc  \
# 0       2012-01-01 00:00:00.000  ...    ANNUAL
# 1       2012-01-01 00:00:00.000  ...    ANNUAL
# 2       2012-01-01 00:00:00.000  ...    ANNUAL
# 3       2012-01-01 00:00:00.000  ...    ANNUAL
# 4       2012-01-01 00:00:00.000  ...    ANNUAL
# ...                         ...  ...       ...
# 110725  2012-01-01 00:00:00.000  ...    ANNUAL
# 110726  2012-01-01 00:00:00.000  ...    ANNUAL
# 110727  2012-01-01 00:00:00.000  ...    ANNUAL
# 110728  2012-01-01 00:00:00.000  ...    ANNUAL
# 110729  2012-01-01 00:00:00.000  ...    ANNUAL
#
#                                            domaincat_desc agg_level_desc  \
# 0                   IRRIGATION STATUS: (ANY ON OPERATION)          STATE
# 1       IRRIGATION STATUS: (HARVESTED CROPLAND IS ENTI...          STATE
# 2                  IRRIGATION STATUS: (NONE ON OPERATION)          STATE
# 3                             NAICS CLASSIFICATION: (111)          STATE
# 4                            NAICS CLASSIFICATION: (1111)          STATE
# ...                                                   ...            ...
# 110725                                      NOT SPECIFIED          STATE
# 110726                                      NOT SPECIFIED          STATE
# 110727                                      NOT SPECIFIED          STATE
# 110728                                      NOT SPECIFIED          STATE
# 110729                                      NOT SPECIFIED          STATE
#
#         year asd_desc         util_practice_desc region_desc sector_desc  \
# 0       2007           ALL UTILIZATION PRACTICES                   CROPS
# 1       2007           ALL UTILIZATION PRACTICES                   CROPS
# 2       2007           ALL UTILIZATION PRACTICES                   CROPS
# 3       2007           ALL UTILIZATION PRACTICES                   CROPS
# 4       2007           ALL UTILIZATION PRACTICES                   CROPS
# ...      ...      ...                        ...         ...         ...
# 110725  2007           ALL UTILIZATION PRACTICES                   CROPS
# 110726  2007           ALL UTILIZATION PRACTICES                   CROPS
# 110727  2007           ALL UTILIZATION PRACTICES                   CROPS
# 110728  2007                        FRESH MARKET                   CROPS
# 110729  2007                        FRESH MARKET                   CROPS
#
#        watershed_desc zip_5
# 0
# 1
# 2
# 3
# 4
# ...               ...   ...
# 110725
# 110726
# 110727
# 110728
# 110729
#
# [110730 rows x 39 columns]

# %%
call4 = "https://quickstats.nass.usda.gov/api/api_GET/?key=" + api_key + "&source_desc=CENSUS&sector_desc=CROPS&agg_level_desc=STATE&year=2002&state_alpha="

res_2002 = []
states = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'IA','ME', 'MD','MA', 'MI','MN', 'MS','MO', 'MT','NE','NV','NH', 'NJ','NM', 'NY','NC', 'ND','OH', 'OK','OR', 'PA','RI','SC','SD', 'TN','TX','UT','VT','VA','WA','WV','WI','WY']  # List of states to iterate over

for state in states:
    endpoint4 = call4 + state  
    result = requests.get(endpoint4)  
    res_2002.append(result.json())  
    print(result)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
total_2002df = pd.DataFrame()  # Initialize an empty DataFrame to store the merged results

for x in range(50):
    df = pd.json_normalize(res_2002[x]['data'])
    total_2002df = pd.concat([total_2002df, df], ignore_index=True)

# %%
call5 = "https://quickstats.nass.usda.gov/api/api_GET/?key=" + api_key + "&source_desc=CENSUS&sector_desc=CROPS&agg_level_desc=STATE&year=1997&state_alpha="

res_1997 = []
states = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'IA','ME', 'MD','MA', 'MI','MN', 'MS','MO', 'MT','NE','NV','NH', 'NJ','NM', 'NY','NC', 'ND','OH', 'OK','OR', 'PA','RI','SC','SD', 'TN','TX','UT','VT','VA','WA','WV','WI','WY']  # List of states to iterate over

for state in states:
    endpoint5 = call5 + state  
    result = requests.get(endpoint5)  
    res_1997.append(result.json())  
    print(result)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
total_1997df = pd.DataFrame()  # Initialize an empty DataFrame to store the merged results

for x in range(50):
    df = pd.json_normalize(res_1997[x]['data'])
    total_1997df = pd.concat([total_1997df, df], ignore_index=True)
